# %%
# importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# %matplotlib inline

# %%
# loading the dataset
from sklearn.datasets import load_boston
boston_dataset = load_boston()

print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
# getting the column names
boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
print(boston_dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston = pd.DataFrame(boston_dataset.data , columns = boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston['MEDV'] = boston_dataset.target
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# checking if there are any missing values
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# variable identification
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
boston.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
fig = plt.figure(figsize=(15,50))
axes1 = fig.add_subplot(6,2,1)
axes2 = fig.add_subplot(6,2,2)
axes3 = fig.add_subplot(6,2,3)
axes4 = fig.add_subplot(6,2,4)
axes5 = fig.add_subplot(6,2,5)
axes6 = fig.add_subplot(6,2,6)
axes7 = fig.add_subplot(6,2,7)
axes8 = fig.add_subplot(6,2,8)
axes9 = fig.add_subplot(6,2,9)
axes10 = fig.add_subplot(6,2,10)
axes11 = fig.add_subplot(6,2,11)
axes12 = fig.add_subplot(6,2,12)

axes1.hist(boston['CRIM'])
axes1.set_title("histogram of per capita crime rate by town")
axes1.set_ylabel("Frequency")
axes1.set_xlabel('per capita crime rate by town')

axes2.hist(boston['ZN'])
axes2.set_title("histogram of proportion of residential land zoned for lots over 25,000 sq.ft.")
axes2.set_ylabel("Frequency")
axes2.set_xlabel('proportion of residential land zoned for lots over 25,000 sq.ft.')

axes3.hist(boston['INDUS'])
axes3.set_title("histogram of proportion of non-retail business acres per town")
axes3.set_ylabel("Frequency")
axes3.set_xlabel('proportion of non-retail business acres per town')

axes4.hist(boston['NOX'])
axes4.set_title("histogram of nitric oxides concentration (parts per 10 million)")
axes4.set_ylabel("Frequency")
axes4.set_xlabel('nitric oxides concentration (parts per 10 million)')

axes5.hist(boston['RM'])
axes5.set_title("histogram of average number of rooms per dwelling")
axes5.set_ylabel("Frequency")
axes5.set_xlabel('average number of rooms per dwelling')

axes6.hist(boston['AGE'])
axes6.set_title("histogram of proportion of owner-occupied units built prior to 1940")
axes6.set_ylabel("Frequency")
axes6.set_xlabel('proportion of owner-occupied units built prior to 1940')

axes7.hist(boston['DIS'])
axes7.set_title("histogram of weighted distances to five Boston employment centres")
axes7.set_ylabel("Frequency")
axes7.set_xlabel('weighted distances to five Boston employment centres')

axes8.hist(boston['RAD'])
axes8.set_title("histogram of index of accessibility to radial highways")
axes8.set_ylabel("Frequency")
axes8.set_xlabel('index of accessibility to radial highways')

axes9.hist(boston['TAX'])
axes9.set_title("histogram of full-value property-tax rate per $10,000")
axes9.set_ylabel("Frequency")
axes9.set_xlabel('full-value property-tax rate per $10,000')

axes10.hist(boston['PTRATIO'])
axes10.set_title("histogram of pupil-teacher ratio by town")
axes10.set_ylabel("Frequency")
axes10.set_xlabel('pupil-teacher ratio by town')

axes11.hist(boston['B'])
axes11.set_title("histogram of 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town")
axes11.set_ylabel("Frequency")
axes11.set_xlabel('1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town')

axes12.hist(boston['LSTAT'])
axes12.set_title("histogram of % lower status of the population")
axes12.set_ylabel("Frequency")
axes12.set_xlabel('% lower status of the population')
# Out:
# Text(0.5, 0, '% lower status of the population')

# %% [markdown]
# # Bi-variate Analysis

# %%
fig = plt.figure(figsize=(15,50))
axes1 = fig.add_subplot(6,2,1)
axes2 = fig.add_subplot(6,2,2)
axes3 = fig.add_subplot(6,2,3)
axes4 = fig.add_subplot(6,2,4)
axes5 = fig.add_subplot(6,2,5)
axes6 = fig.add_subplot(6,2,6)
axes7 = fig.add_subplot(6,2,7)
axes8 = fig.add_subplot(6,2,8)
axes9 = fig.add_subplot(6,2,9)
axes10 = fig.add_subplot(6,2,10)
axes11 = fig.add_subplot(6,2,11)
axes12 = fig.add_subplot(6,2,12)

axes1.scatter(boston['CRIM'],boston['MEDV'])
axes1.set_title("histogram of per capita crime rate by town")
axes1.set_ylabel("Median value of owner-occupied homes in $1000's")
axes1.set_xlabel('per capita crime rate by town')

axes2.scatter(boston['ZN'],boston['MEDV'])
axes2.set_title("histogram of proportion of residential land zoned for lots over 25,000 sq.ft.")
axes2.set_ylabel("Median value of owner-occupied homes in $1000's")
axes2.set_xlabel('proportion of residential land zoned for lots over 25,000 sq.ft.')

axes3.scatter(boston['INDUS'],boston['MEDV'])
axes3.set_title("histogram of proportion of non-retail business acres per town")
axes3.set_ylabel("Median value of owner-occupied homes in $1000's")
axes3.set_xlabel('proportion of non-retail business acres per town')

axes4.scatter(boston['NOX'],boston['MEDV'])
axes4.set_title("histogram of nitric oxides concentration (parts per 10 million)")
axes4.set_ylabel("Median value of owner-occupied homes in $1000's")
axes4.set_xlabel('nitric oxides concentration (parts per 10 million)')

axes5.scatter(boston['RM'],boston['MEDV'])
axes5.set_title("histogram of average number of rooms per dwelling")
axes5.set_ylabel("Median value of owner-occupied homes in $1000's")
axes5.set_xlabel('average number of rooms per dwelling')

axes6.scatter(boston['AGE'],boston['MEDV'])
axes6.set_title("histogram of proportion of owner-occupied units built prior to 1940")
axes6.set_ylabel("Median value of owner-occupied homes in $1000's")
axes6.set_xlabel('proportion of owner-occupied units built prior to 1940')

axes7.scatter(boston['DIS'],boston['MEDV'])
axes7.set_title("histogram of weighted distances to five Boston employment centres")
axes7.set_ylabel("Median value of owner-occupied homes in $1000's")
axes7.set_xlabel('weighted distances to five Boston employment centres')

axes8.scatter(boston['RAD'],boston['MEDV'])
axes8.set_title("histogram of index of accessibility to radial highways")
axes8.set_ylabel("Median value of owner-occupied homes in $1000's")
axes8.set_xlabel('index of accessibility to radial highways')

axes9.scatter(boston['TAX'],boston['MEDV'])
axes9.set_title("histogram of full-value property-tax rate per $10,000")
axes9.set_ylabel("Median value of owner-occupied homes in $1000's")
axes9.set_xlabel('full-value property-tax rate per $10,000')

axes10.scatter(boston['PTRATIO'],boston['MEDV'])
axes10.set_title("histogram of pupil-teacher ratio by town")
axes10.set_ylabel("Median value of owner-occupied homes in $1000's")
axes10.set_xlabel('pupil-teacher ratio by town')

axes11.scatter(boston['B'],boston['MEDV'])
axes11.set_title("histogram of 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town")
axes11.set_ylabel("Median value of owner-occupied homes in $1000's")
axes11.set_xlabel('1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town')

axes12.scatter(boston['LSTAT'],boston['MEDV'])
axes12.set_title("histogram of % lower status of the population")
axes12.set_ylabel("Median value of owner-occupied homes in $1000's")
axes12.set_xlabel('% lower status of the population')
# Out:
# Text(0.5, 0, '% lower status of the population')

# %%
plt.subplots(figsize=(8,7))
correlation_matrix = boston.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# # Defining Performance metric

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true,y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    return r2_score(y_true,y_predict)

# %% [markdown]
# # Shuffle and Split

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(boston.loc[:,boston.columns != 'MEDV'], boston['MEDV'], test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %% [markdown]
# # Analysing Model Performance
# ## Learning Curves

# %%
import warnings
warnings.filterwarnings("ignore", category = UserWarning, module = "matplotlib")

# Producing learning curves for varying training set sizes 
# and maximum depths

from sklearn.model_selection import learning_curve
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import ShuffleSplit

def ModelLearning(X,y):
    """ Calculates the performance of several models with varying sizes of training data.
        The learning and testing scores for each model are then plotted. """
    
    # Creating 10 cross validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2 , random_state = 28)
    
    # Generate the training set sizes increasing by 50
    train_sizes = np.rint(np.linspace(1,X.shape[0]*0.8 - 1,9)).astype(int)
    
    # Create the figure window
    fig = plt.figure(figsize=(10,10))
    
    # Create 4 different models based on max_depth
    for k, depth in enumerate([1,3,6,10]):
        
        # Create a decision tree regressor at max_depth = depth
        regressor = DecisionTreeRegressor(max_depth = depth)
        
        # Calculate the training and testing scores
        sizes, train_scores, test_scores = learning_curve(regressor,\
        X, y, cv = cv, train_sizes = train_sizes, scoring = 'r2')
        
        # Find the mean and standard deviation for smoothing
        train_std = np.std(train_scores, axis = 1)
        train_mean = np.mean(train_scores, axis = 1)
        test_std = np.std(test_scores, axis = 1)
        test_mean = np.mean(test_scores, axis = 1)
        
        # Subplot the learning curve
        ax = fig.add_subplot(2,2, k+1)
        ax.plot(sizes, train_mean, 'o-', color = 'r', label = 'Training Score')
        ax.plot(sizes, test_mean, 'o-', color = 'g', label = 'Testing score')
        ax.fill_between(sizes, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
        ax.fill_between(sizes, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')
        
        # Labels
        ax.set_title('max_Depth = %s'%(depth))
        ax.set_xlabel('Number of Training Points')
        ax.set_ylabel('Score')
        ax.set_xlim([0,X.shape[0]*0.8])
        ax.set_ylim([-0.05,1.05])
        
    # Visual aesthetics
    ax.legend(bbox_to_anchor=(1.05,2.05), loc='lower left', borderaxespad = 0.)
    fig.suptitle('Decision Tree Regressor Learning Performances', fontsize = 16, y = 1.03)
    fig.tight_layout()
    fig.show()
    
    
# calling method
ModelLearning(X_train, y_train)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
# ...

# %%
from sklearn.model_selection import validation_curve
def ModelComplexity(X, y):
    """ Calculates the performance of the model as model complexity increases.
        The learning and testing errors rates are then plotted. """
    
    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)
    
    # Vary the max_depth parameter from 1 to 10
    max_depth = np.arange(1,11)
    
    # Calculate the training and testing scores
    train_scores, test_scores = validation_curve(DecisionTreeRegressor(),\
    X, y, param_name = "max_depth" , param_range = max_depth , \
    cv = cv, scoring = 'r2')
    
    # Find the mean and standard deviation for smoothing
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    
    # Plot the validation curve
    plt.figure(figsize=(7,5))
    plt.title('Decision Tree Regressor Complexity Performance')
    plt.plot(max_depth, train_mean, 'o-', color = 'r', label = 'Training Score')
    plt.plot(max_depth, test_mean, 'o-', color = 'g', label = 'Validation Score')
    plt.fill_between(max_depth, train_mean - train_std, \
    train_mean + train_std, alpha =0.15, color ='r')
    plt.fill_between(max_depth, test_mean - test_std, \
    test_mean + test_std, alpha = 0.15, color = 'g')
    
    # Visual aesthetics
    plt.legend(loc = 'lower right')
    plt.xlabel('Maximum Depth')
    plt.ylabel('Score')
    plt.ylim([-0.05,1.05])
    plt.show()
    
ModelComplexity(X_train,y_train)

# %% [markdown]
# # Fitting the model
# ## ( Decision Tree )

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV

def fit_model(X,y):
    """ Performs grid search over the 'max_depth' parameter for a 
        decision tree regressor trained on the input data [X, y]. """
    
    #Create cross-validation sets from the training data
    cv_sets = ShuffleSplit(n_splits = 10, test_size = 0.20, \
                          random_state = 0)
    
    # decision tree regressor object
    regressor = DecisionTreeRegressor()
    
    # dictionary for the parameter 'max_depth' with a range from 1 to 10
    params = {'max_depth':np.arange(1,11)}
    
    scoring_fnc = make_scorer(performance_metric)
    
    # grid dearch cv object
    grid = GridSearchCV(regressor,params,scoring_fnc,cv = cv_sets)
  
    # fitting the grid dearch object to the data to compute optimal model
    grid = grid.fit(X,y)
    
    # return the optimal model after fitting the data
    return grid.best_estimator_

# %%
# Fit the training data to the model using grid search
reg = fit_model(X_train, y_train)

# Produce the value for 'max_depth'
print("Parameter 'max_depth' is {} for the optimal model.".format(reg.get_params()['max_depth']))
# Out:
# Parameter 'max_depth' is 7 for the optimal model.

# %% [markdown]
# # Fitting linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_model = LinearRegression()
lin_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# model evaluation for training set
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train,y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test,y_test_predict)))
r2 = r2_score(y_test,y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 4.6520331848801675
# R2 score is 0.7508856358979673
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 4.928602182665355
# R2 score is 0.6687594935356294

# %%
# plotting scatter plot of prices vs predicted prices from training set

plt.scatter(y_train,y_train_predict)
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
plt.plot(y_train,y_train,'r-',alpha=0.7)

# %%
# plotting scatter plot of prices vs predicted prices from test set

plt.scatter(y_test,y_test_predict)
plt
plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
plt.plot(y_test,y_test,'r-',alpha=0.6)
